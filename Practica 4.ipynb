# %% [markdown]
# <a href="https://colab.research.google.com/github/NoeEzequiel/Probabiidad/blob/main/Practica%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practica 4
# Alumno: Noe Ezequiel Rodriguez Dominguez
# Maestro: José Gabriel Rodríguez Rivas

# %%
#Libreria de python para generar numeros reales aleatrorios
import random
#Libreria de python para graficar
import matplotlib.pyplot as plt
from statistics import*
#Libreria de dataframe
import pandas as pd
#Libreria de funciones matemáticas
import math

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [57.13, 55.94, 91.12, 65.96, 69.22, 69.57, 93.39, 61.57, 63.09, 82.44, 56.88, 54.9, 64.75, 82.88, 74.29, 61.54, 53.95, 71.91, 54.05, 85.06, 64.59, 71.98, 97.09, 96.27, 89.13, 56.21, 58.0, 71.75, 63.88, 91.61, 93.02, 80.92, 98.53, 60.84, 53.3, 90.77, 77.71, 76.66, 54.37, 77.43, 70.78, 54.64, 68.98, 91.37, 54.97, 57.04, 63.81, 84.87, 82.34, 52.2, 61.1, 65.49, 51.93, 84.57, 73.7, 69.69, 84.78, 90.39, 99.52, 89.91, 78.27, 94.52, 80.9, 70.75, 97.35, 58.13, 77.45, 67.91, 59.73, 64.69, 88.68, 52.66, 88.62, 88.48, 76.52, 91.41, 58.13, 50.19, 86.73, 90.65, 74.4, 78.64, 65.54, 91.16, 67.64, 75.94, 75.89, 91.02, 74.81, 51.62, 98.58, 66.12, 64.61, 95.3, 89.33, 81.21, 76.07, 51.31, 79.18, 85.18]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [88.94, 83.09, 59.19, 68.93, 82.68, 65.79, 87.14, 55.15, 55.42, 66.69, 92.44, 83.85, 70.01, 65.45, 98.29, 58.82, 86.27, 52.11, 80.29, 87.67, 64.74, 67.55, 62.53, 81.5, 81.29, 60.62, 58.29, 50.79, 98.48, 75.29, 99.17, 63.83, 84.02, 63.14, 75.94, 94.39, 75.33, 73.71, 86.31, 82.0, 54.24, 66.64, 85.06, 96.34, 88.42, 99.26, 92.16, 88.56, 94.55, 63.84, 69.49, 88.56, 67.1, 94.7, 80.06, 99.41, 84.9, 52.78, 65.32, 52.83, 74.45, 64.46, 53.32, 98.08, 61.65, 52.54, 96.55, 57.78, 81.6, 61.02, 69.22, 88.75, 66.16, 64.55, 98.64, 51.97, 73.19, 80.15, 65.84, 74.64, 54.34, 62.68, 61.72, 78.11, 90.76, 68.39, 96.51, 56.85, 83.85, 87.25, 66.81, 95.72, 56.07, 56.77, 54.91, 87.19, 78.52, 87.92, 54.94, 79.2]

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("valores de la fabrica 1")
print("La media es: ",media1)
print("la moda es: ",moda1)
print("La mediana es: ", mediana1)
# Out:
# valores de la fabrica 1
# La media es:  74.011
# la moda es:  58.13
# La mediana es:  74.345

# %%
media = mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("La media es: ",media)
print("la moda es: ",moda)
print("La mediana es: ", mediana)
# Out:
# valores de la fabrica 2
# La media es:  74.6443
# la moda es:  83.85
# La mediana es:  74.545

# %%
#generar sublot de un renglon por dos columnas
fig,(ax1, ax2)= plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo, valor maximo y el rango

# %%
plt.hist(fabrica1, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media1, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana1, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=20, alpha =0.2, color='blue', edgecolor='black')
plt.axvline(media, color='r', linestyle='dashed', linewidth=2, label=('Media'))
plt.axvline(mediana, color='purple', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda, color='g', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# Maximo, minimo y rango

# %%
maximo = max (fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media1 = mean (fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
print("estadisticas de la fabrica 1: maximo", maximo," minimo", minimo," rango", rango," media", media1, " mediana", mediana1," moda", moda1)
# Out:
# estadisticas de la fabrica 1: maximo 99.52  minimo 50.19  rango 49.33  media 74.011  mediana 74.345  moda 58.13

# %%
maximo = max (fabrica2)
minimo = min(fabrica2)
rango = maximo - minimo
media = mean (fabrica2)
mediana= median(fabrica2)
moda= mode(fabrica2)
print("estadisticas de la fabrica 1: maximo", maximo,"\n minimo", minimo," \nrango", rango," \nmedia", media, " \n mediana", mediana," \n moda", moda)
# Out:
# estadisticas de la fabrica 1: maximo 99.41
#  minimo 50.79
# rango 48.62
# media 74.6443
#  mediana 74.545
#  moda 83.85

# %% [markdown]
# Dispersion de datos

# %%
Desviacionestandar_fabrica1=stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es: ",Desviacionestandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es:  14.302524288044436

# %%
Desviacionestandar_fabrica2=stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es: ",Desviacionestandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es:  14.709900689431228

# %%
plt.figure(figsize=(11,8))
plt.hist(fabrica1, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media1, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana1, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.axvline(media1 - Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2,label=f'Desviacion estandar={Desviacionestandar_fabrica1:.2f}')
plt.axvline(media1 + Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.hist(fabrica2, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.axvline(media - Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2,label=f'Desviacion estandar={Desviacionestandar_fabrica1:.2f}')
plt.axvline(media + Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
edades=[]
for i in range (100):
  num_aleatorio=random.randint(18,70)
  edades.append(num_aleatorio)
print(edades)
# Out:
# [65, 59, 49, 65, 53, 21, 20, 31, 38, 24, 20, 63, 44, 52, 60, 62, 24, 53, 51, 66, 32, 69, 57, 38, 35, 60, 46, 70, 42, 54, 53, 36, 54, 55, 54, 68, 20, 19, 28, 62, 39, 21, 43, 55, 64, 36, 32, 41, 20, 22, 20, 66, 52, 39, 32, 44, 63, 18, 33, 29, 34, 46, 41, 26, 39, 24, 42, 50, 62, 31, 26, 37, 26, 70, 53, 49, 62, 25, 19, 63, 28, 20, 62, 27, 55, 20, 26, 36, 56, 56, 32, 63, 46, 24, 23, 63, 38, 32, 53, 19]

# %%
df_edades= pd.DataFrame(edades, columns=["edades"])
df_edades
# Out:
#     edades
# 0       65
# 1       59
# 2       49
# 3       65
# 4       53
# ..     ...
# 95      63
# 96      38
# 97      32
# 98      53
# 99      19
#
# [100 rows x 1 columns]

# %%
tabla_frecuencias=df_edades['edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 35    18           1
# 13    19           3
# 0     20           7
# 26    21           2
# 36    22           1
# 44    23           1
# 6     24           4
# 29    25           1
# 5     26           4
# 28    27           1
# 15    28           2
# 33    29           1
# 20    31           2
# 3     32           5
# 27    33           1
# 32    34           1
# 34    35           1
# 12    36           3
# 30    37           1
# 9     38           3
# 11    39           3
# 16    41           2
# 19    42           2
# 39    43           1
# 25    44           2
# 10    46           3
# 21    49           2
# 31    50           1
# 41    51           1
# 24    52           2
# 2     53           5
# 8     54           3
# 7     55           3
# 17    56           2
# 37    57           1
# 43    59           1
# 23    60           2
# 4     62           5
# 1     63           5
# 38    64           1
# 14    65           2
# 22    66           2
# 40    68           1
# 42    69           1
# 18    70           2

# %%
tabla_frecuencias["Frec.Relativa"]=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa
# 35    18           1           0.01
# 13    19           3           0.03
# 0     20           7           0.07
# 26    21           2           0.02
# 36    22           1           0.01
# 44    23           1           0.01
# 6     24           4           0.04
# 29    25           1           0.01
# 5     26           4           0.04
# 28    27           1           0.01
# 15    28           2           0.02
# 33    29           1           0.01
# 20    31           2           0.02
# 3     32           5           0.05
# 27    33           1           0.01
# 32    34           1           0.01
# 34    35           1           0.01
# 12    36           3           0.03
# 30    37           1           0.01
# 9     38           3           0.03
# 11    39           3           0.03
# 16    41           2           0.02
# 19    42           2           0.02
# 39    43           1           0.01
# 25    44           2           0.02
# 10    46           3           0.03
# 21    49           2           0.02
# 31    50           1           0.01
# 41    51           1           0.01
# 24    52           2           0.02
# 2     53           5           0.05
# 8     54           3           0.03
# 7     55           3           0.03
# 17    56           2           0.02
# 37    57           1           0.01
# 43    59           1           0.01
# 23    60           2           0.02
# 4     62           5           0.05
# 1     63           5           0.05
# 38    64           1           0.01
# 14    65           2           0.02
# 22    66           2           0.02
# 40    68           1           0.01
# 42    69           1           0.01
# 18    70           2           0.02

# %%
tabla_frecuencias["frec.porcentual"]=tabla_frecuencias["Frecuencia"]/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa  frec.porcentual
# 35    18           1           0.01              1.0
# 13    19           3           0.03              3.0
# 0     20           7           0.07              7.0
# 26    21           2           0.02              2.0
# 36    22           1           0.01              1.0
# 44    23           1           0.01              1.0
# 6     24           4           0.04              4.0
# 29    25           1           0.01              1.0
# 5     26           4           0.04              4.0
# 28    27           1           0.01              1.0
# 15    28           2           0.02              2.0
# 33    29           1           0.01              1.0
# 20    31           2           0.02              2.0
# 3     32           5           0.05              5.0
# 27    33           1           0.01              1.0
# 32    34           1           0.01              1.0
# 34    35           1           0.01              1.0
# 12    36           3           0.03              3.0
# 30    37           1           0.01              1.0
# 9     38           3           0.03              3.0
# 11    39           3           0.03              3.0
# 16    41           2           0.02              2.0
# 19    42           2           0.02              2.0
# 39    43           1           0.01              1.0
# 25    44           2           0.02              2.0
# 10    46           3           0.03              3.0
# 21    49           2           0.02              2.0
# 31    50           1           0.01              1.0
# 41    51           1           0.01              1.0
# 24    52           2           0.02              2.0
# 2     53           5           0.05              5.0
# 8     54           3           0.03              3.0
# 7     55           3           0.03              3.0
# 17    56           2           0.02              2.0
# 37    57           1           0.01              1.0
# 43    59           1           0.01              1.0
# 23    60           2           0.02              2.0
# 4     62           5           0.05              5.0
# 1     63           5           0.05              5.0
# 38    64           1           0.01              1.0
# 14    65           2           0.02              2.0
# 22    66           2           0.02              2.0
# 40    68           1           0.01              1.0
# 42    69           1           0.01              1.0
# 18    70           2           0.02              2.0

# %%
tabla_frecuencias["Frecuencia acumulada"]=tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa  frec.porcentual  Frecuencia acumulada
# 35    18           1           0.01              1.0                     1
# 13    19           3           0.03              3.0                     4
# 0     20           7           0.07              7.0                    11
# 26    21           2           0.02              2.0                    13
# 36    22           1           0.01              1.0                    14
# 44    23           1           0.01              1.0                    15
# 6     24           4           0.04              4.0                    19
# 29    25           1           0.01              1.0                    20
# 5     26           4           0.04              4.0                    24
# 28    27           1           0.01              1.0                    25
# 15    28           2           0.02              2.0                    27
# 33    29           1           0.01              1.0                    28
# 20    31           2           0.02              2.0                    30
# 3     32           5           0.05              5.0                    35
# 27    33           1           0.01              1.0                    36
# 32    34           1           0.01              1.0                    37
# 34    35           1           0.01              1.0                    38
# 12    36           3           0.03              3.0                    41
# 30    37           1           0.01              1.0                    42
# 9     38           3           0.03              3.0                    45
# 11    39           3           0.03              3.0                    48
# 16    41           2           0.02              2.0                    50
# 19    42           2           0.02              2.0                    52
# 39    43           1           0.01              1.0                    53
# 25    44           2           0.02              2.0                    55
# 10    46           3           0.03              3.0                    58
# 21    49           2           0.02              2.0                    60
# 31    50           1           0.01              1.0                    61
# 41    51           1           0.01              1.0                    62
# 24    52           2           0.02              2.0                    64
# 2     53           5           0.05              5.0                    69
# 8     54           3           0.03              3.0                    72
# 7     55           3           0.03              3.0                    75
# 17    56           2           0.02              2.0                    77
# 37    57           1           0.01              1.0                    78
# 43    59           1           0.01              1.0                    79
# 23    60           2           0.02              2.0                    81
# 4     62           5           0.05              5.0                    86
# 1     63           5           0.05              5.0                    91
# 38    64           1           0.01              1.0                    92
# 14    65           2           0.02              2.0                    94
# 22    66           2           0.02              2.0                    96
# 40    68           1           0.01              1.0                    97
# 42    69           1           0.01              1.0                    98
# 18    70           2           0.02              2.0                   100

# %% [markdown]
# Regla de sturges
#
# 1.- Es una regla que sirve para calucular el numero de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos

# %%
print(edades)
# Out:
# [65, 59, 49, 65, 53, 21, 20, 31, 38, 24, 20, 63, 44, 52, 60, 62, 24, 53, 51, 66, 32, 69, 57, 38, 35, 60, 46, 70, 42, 54, 53, 36, 54, 55, 54, 68, 20, 19, 28, 62, 39, 21, 43, 55, 64, 36, 32, 41, 20, 22, 20, 66, 52, 39, 32, 44, 63, 18, 33, 29, 34, 46, 41, 26, 39, 24, 42, 50, 62, 31, 26, 37, 26, 70, 53, 49, 62, 25, 19, 63, 28, 20, 62, 27, 55, 20, 26, 36, 56, 56, 32, 63, 46, 24, 23, 63, 38, 32, 53, 19]

# %%
plt.hist(edades, alpha=0.5, rwidth=0.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("edades")
plt.ylabel("Frecuencias")
# Out:
# Text(0, 0.5, 'Frecuencias')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     65
# 1     59
# 2     49
# 3     65
# 4     53
# ..   ...
# 95    63
# 96    38
# 97    32
# 98    53
# 99    19
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1+math.log2(n))
print("el valor de n= ",n," valor de num de intervalos= ", k)
# Out:
# el valor de n=  100  valor de num de intervalos=  7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges['Edad'], bins=k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (17.948, 25.429]    20
# 1  (47.714, 55.143]    17
# 2  (25.429, 32.857]    15
# 3    (62.571, 70.0]    14
# 4  (32.857, 40.286]    13
# 5  (55.143, 62.571]    11
# 6  (40.286, 47.714]    10

# %%
tabla_frec_sturges.columns=['Clase','Frecuencia']
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          20
# 1  (47.714, 55.143]          17
# 2  (25.429, 32.857]          15
# 3    (62.571, 70.0]          14
# 4  (32.857, 40.286]          13
# 5  (55.143, 62.571]          11
# 6  (40.286, 47.714]          10

# %%
tabla_frec_sturges=tabla_frec_sturges.sort_values(by ='Clase')
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          20
# 2  (25.429, 32.857]          15
# 4  (32.857, 40.286]          13
# 6  (40.286, 47.714]          10
# 1  (47.714, 55.143]          17
# 5  (55.143, 62.571]          11
# 3    (62.571, 70.0]          14

# %%
tabla_frec_sturges['Frec.relativa']=tabla_frec_sturges['Frecuencia']/n
tabla_frec_sturges['Frec.porcentual']=tabla_frec_sturges['Frecuencia']/n*100
tabla_frec_sturges['Frec.acumulada']=tabla_frec_sturges['Frecuencia'].cumsum()
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec.relativa  Frec.porcentual  \
# 0  (17.948, 25.429]          20           0.20             20.0
# 2  (25.429, 32.857]          15           0.15             15.0
# 4  (32.857, 40.286]          13           0.13             13.0
# 6  (40.286, 47.714]          10           0.10             10.0
# 1  (47.714, 55.143]          17           0.17             17.0
# 5  (55.143, 62.571]          11           0.11             11.0
# 3    (62.571, 70.0]          14           0.14             14.0
#
#    Frec.acumulada
# 0              20
# 2              35
# 4              48
# 6              58
# 1              75
# 5              86
# 3             100

# %%
plt.hist(df_edades_sturges['Edad'], bins=k, alpha=0.5,rwidth=0.95)
plt.title("Histograma basado en la regla de Sturges")
plt.xlabel("edades")
plt.ylabel("Frecuencias")
# Out:
# Text(0, 0.5, 'Frecuencias')
