# %% [markdown]
# <a href="https://colab.research.google.com/github/NoeEzequiel/Probabiidad/blob/main/Practica%201%20y%202.%20Estadisica%20descriptiva%20b%C3%A1sica%20e%20Histogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practica 1 y 2 Estadisica descriptiva básica e Histogramas
# Alumno: Noe Ezequiel Rodriguez Dominguez
# Maestro: José Gabriel Rodríguez Rivas

# %%
#Libreria de python para generar numeros reales aleatrorios
import random
#Libreria de python para graficar
import matplotlib.pyplot as plt
from statistics import*

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [74.86, 67.15, 93.67, 61.07, 91.41, 95.35, 68.33, 59.86, 81.46, 76.8, 86.28, 79.72, 68.29, 78.69, 75.61, 87.55, 72.94, 93.04, 99.73, 98.24, 51.66, 54.89, 56.77, 86.51, 99.64, 98.84, 63.35, 90.07, 68.88, 63.55, 69.68, 67.66, 53.77, 56.42, 87.54, 63.72, 70.06, 89.63, 64.88, 60.69, 91.8, 93.03, 98.18, 73.27, 95.64, 80.4, 95.49, 80.09, 62.36, 82.8, 51.22, 80.71, 66.87, 88.75, 89.04, 66.22, 69.91, 59.86, 84.18, 85.53, 88.69, 61.08, 56.48, 81.19, 93.72, 96.82, 77.26, 84.69, 94.34, 73.15, 89.55, 92.44, 77.89, 88.08, 88.13, 50.58, 58.87, 70.21, 95.78, 53.38, 81.98, 56.27, 68.09, 74.42, 72.39, 68.33, 56.15, 86.38, 62.25, 65.88, 62.14, 72.99, 94.35, 96.14, 60.19, 57.07, 98.16, 62.93, 73.32, 84.38]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [80.77, 58.87, 81.14, 54.34, 55.31, 66.31, 80.84, 75.85, 85.91, 80.21, 53.63, 87.9, 76.51, 54.78, 58.72, 54.29, 97.2, 87.25, 86.9, 52.72, 69.9, 53.96, 65.89, 78.88, 77.34, 89.49, 59.84, 72.44, 59.22, 92.89, 71.17, 54.36, 65.74, 65.25, 82.91, 88.29, 73.65, 80.71, 81.36, 58.05, 83.01, 88.06, 91.75, 84.54, 59.92, 79.27, 82.86, 88.19, 83.03, 59.77, 74.44, 52.2, 53.7, 69.42, 97.11, 63.76, 99.95, 57.86, 56.27, 95.79, 76.89, 84.9, 51.51, 57.72, 99.73, 62.62, 60.58, 51.2, 88.51, 81.07, 89.29, 55.78, 97.94, 84.04, 93.41, 81.31, 51.23, 85.62, 82.44, 63.07, 86.04, 52.27, 86.36, 55.49, 72.02, 94.95, 98.04, 78.88, 72.56, 81.1, 67.6, 89.98, 60.5, 50.23, 56.05, 59.64, 83.96, 54.83, 50.45, 66.76]

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("valores de la fabrica 1")
print("La media es: ",media1)
print("la moda es: ",moda1)
print("La mediana es: ", mediana1)
# Out:
# valores de la fabrica 1
# La media es:  76.4975
# la moda es:  68.33
# La mediana es:  76.205

# %%
media = mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("La media es: ",media)
print("la moda es: ",moda)
print("La mediana es: ", mediana)
# Out:
# valores de la fabrica 2
# La media es:  73.0826
# la moda es:  78.88
# La mediana es:  75.145

# %%
#generar sublot de un renglon por dos columnas
fig,(ax1, ax2)= plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo, valor maximo y el rango

# %%
plt.hist(fabrica1, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media1, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana1, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=20, alpha =0.2, color='blue', edgecolor='black')
plt.axvline(media, color='r', linestyle='dashed', linewidth=2, label=('Media'))
plt.axvline(mediana, color='purple', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda, color='g', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
